# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import itertools

# %%
def ends(df, x=5):
    return df.head(x).append(df.tail(x))
setattr(pd.DataFrame,'ends',ends)
setattr(pd.Series,'ends',ends)

# %%
PATH = './../'
PATH_DATA_RAW = PATH + 'data/raw/'
PATH_DATA_INTERMEDIATE = PATH + 'data/intermediate/'
PATH_DATA_PROCESSED = PATH + 'data/processed/'

# %% [markdown]
# # Loading data

# %%
year_init=1995
year_final=2016
which_years = "allyears"
collab_df = pd.read_csv(PATH_DATA_INTERMEDIATE + 'WTCF_0001_reduced_{whichyears}_{year1}-{year2}.csv'.format(year1=year_init, 
                                                                                                      year2=year_final,
                                                                                                     whichyears = which_years), 
                        dtype={'hs_product_code':'str'})
collab_df['hs_product_code'] = collab_df['hs_product_code'].str.zfill(4)
collab_df.shape
# Out:
# (2421903, 6)

# %%
collab_df.ends(2)
# Out:
#         location_code hs_product_code  year     ln_Xcp   ln_share  \
# 0                 AGO            0101  1997   8.520189  -9.554841
# 1                 AGO            0101  2008   8.605753 -11.379036
# 2421901           ANS            9706  2015  15.660364  -8.679755
# 2421902           ANS            9706  2016  17.350427  -8.460051
#
#          mln_mln_share
# 0            -2.257048
# 1            -2.431773
# 2421901      -2.160993
# 2421902      -2.135355

# %%
collab_df.groupby(by=['year']).describe(include='all').T.dropna()
# Out:
# year                        1995      1996      1997      1998      1999  \
# location_code   count      99634    102328    103418    104121    105481
#                 unique       116       116       116       116       116
#                 top          GBR       USA       ANS       ANS       ANS
#                 freq        1221      1221      1221      1221      1221
# hs_product_code count      99634    102328    103418    104121    105481
#                 unique      1221      1221      1221      1221      1221
#                 top         8473      8708      8501      6204      7326
#                 freq         116       116       116       116       116
# ln_Xcp          count      99634    102328    103418    104121    105481
#                 mean     13.2524   13.2651   13.2909   13.2802   13.2273
#                 std      3.39214   3.38135   3.39569   3.39807    3.4068
#                 min      4.60517   4.61512   4.61512   4.60517   4.60517
#                 25%       10.708   10.7284   10.7528    10.718   10.6785
#                 50%      13.2488   13.2534   13.2897   13.2885   13.2126
#                 75%      15.7668   15.7724   15.8112   15.8078   15.7585
#                 max      24.5801   24.6581   24.6485   24.7808   24.8194
# ln_share        count      99634    102328    103418    104121    105481
#                 mean    -9.80788  -9.80458  -9.84909  -9.85926   -9.8828
#                 std       2.6455   2.62941   2.66253   2.66293   2.66129
#                 min     -20.6843  -20.7992  -21.1401  -20.7373  -21.2872
#                 25%      -11.614  -11.5868  -11.6781  -11.6765  -11.6965
#                 50%     -9.72567  -9.72654  -9.75566  -9.77474  -9.79978
#                 75%     -7.93989  -7.94078  -7.95541  -7.96329  -8.00013
#                 max    -0.182683 -0.113224 -0.193918  -0.13138 -0.161999
# mln_mln_share   count      99634    102328    103418    104121    105481
#                 mean    -2.24295  -2.24314   -2.2471  -2.24821  -2.25081
#                 std     0.295465  0.293438  0.295184  0.294932  0.294138
#                 min     -3.02937  -3.03492  -3.05117  -3.03193  -3.05811
#                 25%     -2.45221  -2.44987  -2.45772  -2.45758  -2.45929
#                 50%     -2.27477  -2.27486  -2.27785   -2.2798  -2.28236
#                 75%      -2.0719  -2.07201  -2.07385  -2.07484  -2.07946
#                 max          1.7   2.17838   1.64032   2.02966   1.82017
#
# year                        2000      2001      2002      2003      2004  ...  \
# location_code   count     108815    108562    109517    110723    111544  ...
#                 unique       116       116       116       116       116  ...
#                 top          GBR       CHN       CHN       CHN       USA  ...
#                 freq        1221      1221      1221      1221      1221  ...
# hs_product_code count     108815    108562    109517    110723    111544  ...
#                 unique      1221      1221      1221      1221      1221  ...
#                 top         8473      9403      3923      8704      8483  ...
#                 freq         116       116       116       116       116  ...
# ln_Xcp          count     108815    108562    109517    110723    111544  ...
#                 mean     13.0884   13.1264    13.131   13.2159   13.3722  ...
#                 std      3.54322   3.54082   3.57186   3.60119   3.63855  ...
#                 min      4.60517   4.60517   4.60517   4.60517   4.60517  ...
#                 25%      10.4875   10.5309   10.5239   10.5886   10.7169  ...
#                 50%      13.0941   13.1638   13.1748   13.2792   13.4596  ...
#                 75%      15.7171    15.758   15.7907   15.8968    16.085  ...
#                 max      24.8062   24.9004   25.0356    25.225   25.3204  ...
# ln_share        count     108815    108562    109517    110723    111544  ...
#                 mean    -10.0269  -10.0285  -10.0655  -10.1069  -10.1782  ...
#                 std      2.74998   2.76319   2.79082   2.81208    2.8519  ...
#                 min     -21.9383  -22.0115  -22.0783  -20.8896  -21.6216  ...
#                 25%     -11.8758  -11.8816   -11.943  -11.9923   -12.087  ...
#                 50%      -9.9143  -9.91195  -9.93967  -9.97305   -10.047  ...
#                 75%     -8.07378  -8.05605  -8.07162  -8.09954  -8.13473  ...
#                 max    -0.318342 -0.445768 -0.425686 -0.303969 -0.199642  ...
# mln_mln_share   count     108815    108562    109517    110723    111544  ...
#                 mean    -2.26404  -2.26383  -2.26709  -2.27093  -2.27736  ...
#                 std     0.298253  0.299523   0.30087  0.301787  0.304025  ...
#                 min     -3.08823  -3.09157  -3.09459  -3.03925   -3.0737  ...
#                 25%      -2.4745  -2.47499  -2.48014  -2.48426  -2.49213  ...
#                 50%     -2.29398  -2.29374  -2.29653  -2.29989  -2.30728  ...
#                 75%     -2.08862  -2.08642  -2.08835  -2.09181  -2.09614  ...
#                 max      1.14463  0.807957  0.854053   1.19083   1.61123  ...
#
# year                        2007      2008      2009      2010      2011  \
# location_code   count     113783    113594    112865    113461    113980
#                 unique       116       116       116       116       116
#                 top          USA       CHN       CHN       ZAF       ZAF
#                 freq        1221      1221      1220      1221      1219
# hs_product_code count     113783    113594    112865    113461    113980
#                 unique      1221      1221      1221      1221      1221
#                 top         3926      8544      3004      8409      8415
#                 freq         116       116       116       116       116
# ln_Xcp          count     113783    113594    112865    113461    113980
#                 mean     13.6528    13.771   13.6105    13.696    13.848
#                 std      3.72293   3.74134   3.69535     3.736   3.76189
#                 min      4.60517   4.60517   4.60517   4.60517   4.60517
#                 25%      10.9849    11.115   10.9796   11.0169   11.1699
#                 50%      13.7937   13.9318   13.7729   13.8573   14.0134
#                 75%      16.4218   16.5524   16.3569   16.4907   16.6577
#                 max        25.64   25.6491   25.4729   25.7863   25.9345
# ln_share        count     113783    113594    112865    113461    113980
#                 mean    -10.2597  -10.2867  -10.2156  -10.2951  -10.3183
#                 std      2.94261   2.96998    2.9403   2.97152   2.99402
#                 min     -22.5413  -22.4024  -23.1226  -22.9513  -22.6891
#                 25%     -12.1991  -12.2472  -12.1506  -12.2545  -12.2966
#                 50%      -10.084   -10.101  -10.0204  -10.1146  -10.1369
#                 75%     -8.15205  -8.15578  -8.10455  -8.15731   -8.1699
#                 max    -0.253045 -0.500722 -0.342649 -0.493245 -0.525934
# mln_mln_share   count     113783    113594    112865    113461    113980
#                 mean    -2.28367  -2.28576  -2.27919  -2.28656  -2.28841
#                 std     0.309135  0.310806  0.309365  0.310963  0.312165
#                 min     -3.11535  -3.10917  -3.14081  -3.13337  -3.12188
#                 25%     -2.50137   -2.5053  -2.49738  -2.50589  -2.50933
#                 50%     -2.31095  -2.31263  -2.30463  -2.31398  -2.31618
#                 75%     -2.09827  -2.09873  -2.09243  -2.09891  -2.10046
#                 max      1.37419  0.691705   1.07105   0.70675   0.64258
#
# year                        2012      2013      2014      2015      2016
# location_code   count     113535    112892    112221    112686    112557
#                 unique       116       116       116       116       116
#                 top          ZAF       CHN       CHN       USA       CHN
#                 freq        1221      1214      1217      1215      1213
# hs_product_code count     113535    112892    112221    112686    112557
#                 unique      1221      1221      1221      1221      1221
#                 top         8529      9403      9405      8703      8528
#                 freq         116       116       116       116       116
# ln_Xcp          count     113535    112892    112221    112686    112557
#                 mean     13.8266   13.8335    13.865   13.7143   13.6814
#                 std      3.77536   3.81218   3.81767   3.82757   3.86238
#                 min      4.60517   4.60517   4.60517   4.60517   4.60517
#                 25%      11.1502   11.1158   11.1452   11.0021   10.9331
#                 50%      14.0192   14.0352   14.0689   13.9117   13.9157
#                 75%      16.6432   16.6928   16.7304   16.5772   16.5834
#                 max      26.0802   26.0737   26.0772    25.924   25.8472
# ln_share        count     113535    112892    112221    112686    112557
#                 mean    -10.3261  -10.3467  -10.3439  -10.3715  -10.4017
#                 std      3.01098   3.03427   3.03306   3.04109   3.06317
#                 min     -23.0697  -22.1133  -23.1297  -22.9565  -23.1772
#                 25%     -12.3096  -12.3592  -12.3324  -12.3618  -12.4099
#                 50%      -10.137  -10.1483  -10.1381  -10.1596  -10.1898
#                 75%     -8.15362  -8.15568  -8.15915  -8.18656  -8.19556
#                 max    -0.338728 -0.264672 -0.363668 -0.498353 -0.338175
# mln_mln_share   count     113535    112892    112221    112686    112557
#                 mean    -2.28875  -2.29022  -2.28997  -2.29266  -2.29511
#                 std     0.313566  0.315359  0.315319  0.315242  0.316822
#                 min     -3.13852  -3.09618  -3.14112   -3.1336  -3.14317
#                 25%     -2.51038   -2.5144  -2.51223  -2.51461   -2.5185
#                 50%     -2.31619  -2.31731   -2.3163  -2.31841  -2.32139
#                 75%     -2.09846  -2.09871  -2.09914  -2.10249  -2.10359
#                 max      1.08256   1.32926   1.01151  0.696446   1.08419
#
# [32 rows x 22 columns]

# %%
(collab_df.isnull().sum().sum(), collab_df.isna().sum().sum())
# Out:
# (0, 0)

# %% [markdown]
# # Fast ai

# %%
from fastai import *
from fastai.collab import *

# %% [markdown]
# The model is basically the following:
#
# $$
# \text{argmin}_{a,b,\mathbf{\gamma},\mathbf{\delta}}\sum_{c,p\in\mathcal{O}} \left(r_{c,p} - a_c - b_p  -\mathbf{\delta}^T_p\mathbf{\gamma}_c\right)^2 + w\left( \left\|\mathbf{a}\right\|^2 + \left\|\mathbf{b}\right\|^2 + \left\|\mathbf{\delta}\right\|^2 + \left\|\mathbf{\gamma}\right\|^2\right)
# $$
#
# where $r_{c,p}$ is the rating of country $c$ in product $p$. If $X_{c,p}$ is total exports in a given year, here we will model either $\text{'share'}=\ln(X_{c,p})$ or $\text{'y'}=-\ln(-\ln(X_{c,p}/\sum_p X_{c,p}))$. The minimization is over the embeddings representing countries and products, where $\mathbf{\gamma}_c$ is a vector in $\mathbb{R}^K$ representing country $c$ and $\mathbf{\delta}_p$ is a vector in $\mathbb{R}^K$ representing product $p$. Here, $K$ is the dimension of these embeddings (the lower rank representation of the matrix of ratings). Note that the sum is over the set $\mathcal{O}$, which is the pairs of country-product combinations that are actually _observed_. In other words, we do not impute any missing values.
#
# Notice that we also include some biases, $a_c$ and $b_p$, representing a country or product's inherent average rating.
#
# I say that this is what fastai does "basically", because there is an activation function at the end, which ensures that the ratings are within a fixed range.

# %% [markdown]
# ### Setting some parameters

# %%
# Train year
year_train = 1995

# Test year
year_test = 1995

# Columns
user_col = 'location_code'
item_col='hs_product_code'

# Values
rating_col='ln_share'
prediction_col= 'pred_' + rating_col

# %%
ctry_names = sorted(collab_df[user_col].unique())
prod_names = sorted(collab_df[item_col].unique())

# %%
test_df = pd.DataFrame(list(itertools.product(ctry_names, prod_names)),
                      columns = [user_col, item_col])
# test_df = test_df.merge(collab_df[collab_df['year']==year_test], 
#                         how = 'left',
#                         on=[user_col, item_col])

# %%
print(test_df.shape)
test_df.ends(3)
# Out:
# (141636, 2)
#        location_code hs_product_code
# 0                AGO            0101
# 1                AGO            0102
# 2                AGO            0103
# 141633           ZWE            9704
# 141634           ZWE            9705
# 141635           ZWE            9706

# %%
from scipy.stats import norm

# %%
# Looking at the ranges of the dependent variable, and what a normal distribution would predict
muest = np.mean(collab_df[rating_col])
sdest = np.std(collab_df[rating_col])
num_rows = collab_df[collab_df['year']==year_train].shape[0]
((collab_df[collab_df['year']==year_train][rating_col].min(), 
  collab_df[collab_df['year']==year_train][rating_col].max()), 
(norm.ppf(1.0/num_rows, loc=muest, scale=sdest), 
 norm.ppf(1.0-1.0/num_rows, loc=muest, scale=sdest)))
# Out:
# ((-20.684274585157052, -0.1826831206688979),
#  (-22.43017533232581, 2.1244212748417013))

# %%
dep_range = (norm.ppf(1.0/num_rows, loc=muest, scale=sdest), 
 norm.ppf(1.0-1.0/num_rows, loc=muest, scale=sdest))
dep_range
# Out:
# (-22.43017533232581, 2.1244212748417013)

# %%
data = CollabDataBunch.from_df(collab_df[collab_df['year']==year_train], 
                          user_name = user_col,
                          item_name = item_col,
                          rating_name = rating_col,
                           seed = 42,
                          test = test_df,
                          path = PATH)

# %%
# Checking that there are no classes in the validation/test sets that are only in the training

# Validation
print(set(data.valid_ds.classes[user_col]) - set(data.train_ds.classes[user_col]))
print(set(data.valid_ds.classes[item_col]) - set(data.train_ds.classes[item_col]))

# Test
print(set(data.test_ds.classes[user_col]) - set(data.train_ds.classes[user_col]))
print(set(data.test_ds.classes[item_col]) - set(data.train_ds.classes[item_col]))
# Out:
# set()
# set()
# set()
# set()

# %% [markdown]
# ## Starting the fitting procedure

# %%
learn = collab_learner(data, n_factors=25, y_range=dep_range)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# Min numerical gradient: 6.92E-06

# %%
learn.fit_one_cycle(15, 2e-02, wd=0.1)
# Out:
# Total time: 17:52 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.129294</td>
#       <td>4.039225</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.951388</td>
#       <td>3.972617</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.574734</td>
#       <td>4.553902</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.928165</td>
#       <td>5.036716</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.197347</td>
#       <td>5.113173</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.058234</td>
#       <td>5.020667</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.973612</td>
#       <td>4.820477</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.588459</td>
#       <td>4.462705</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.032167</td>
#       <td>4.280761</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.993963</td>
#       <td>3.929993</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.596661</td>
#       <td>3.591239</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.105720</td>
#       <td>3.377612</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.440003</td>
#       <td>3.302146</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.016342</td>
#       <td>3.292736</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.764789</td>
#       <td>3.299754</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# Min numerical gradient: 6.31E-07

# %%
learn.save('collab_fittedon_{var}_{year1}-{year2}_fit_1'.format(var=rating_col, year1=year_train, year2=year_test))

# %%
learn.fit_one_cycle(5, 1e-06)
# Out:
# Total time: 06:30 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.677153</td>
#       <td>3.299777</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.630193</td>
#       <td>3.299849</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.667107</td>
#       <td>3.299914</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.644880</td>
#       <td>3.299943</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.673024</td>
#       <td>3.299946</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('collab_fittedon_{var}_{year1}-{year2}_fit_2'.format(var=rating_col, year1=year_train, year2=year_test))

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# Min numerical gradient: 6.31E-07

# %%
# learn.fit_one_cycle(2, 2e-01)

# %% [markdown]
# ## load model, if necessary

# %%
load_prev_model = False
# train from previous years
# data = CollabDataBunch.from_df(collab_df[collab_df['year'].isin([1995,2005])])
if load_prev_model:
    data = CollabDataBunch.from_df(collab_df[collab_df['year']==year_train], 
                          user_name = user_col,
                          item_name = item_col,
                          rating_name = rating_col,
                           seed = 42,
                          test = test_df,
                          path = PATH)  

    learn = collab_learner(data, n_factors=25, y_range=dep_range)

    learn = learn.load('collab_fittedon_{var}_{year1}-{year2}_fit_2'.format(var=rating_col, year1=year_train, year2=year_test))

# %% [markdown]
# ## Let's check some results

# %%
from sklearn.metrics import mean_squared_error
def my_rmse(yreal, ypred):
    idxreal = np.where(yreal.notnull())[0]
    idxpred = np.where(ypred.notnull())[0]
    idx = list(set(idxreal).intersection(set(idxpred)))
    return(np.sqrt(mean_squared_error(yreal.iloc[idx], ypred.iloc[idx])))

# %%
learn.show_results()
# Out:
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>location_code</th>
#     <th>hs_product_code</th>
#     <th>target</th>
#     <th>prediction</th>
#   </tr>
#   <tr>
#     <th>DNK</th>
#     <th>0406</th>
#     <th>-3.7936554</th>
#     <th>-4.8156357</th>
#   </tr>
#   <tr>
#     <th>CRI</th>
#     <th>6304</th>
#     <th>-10.912899</th>
#     <th>-11.5429325</th>
#   </tr>
#   <tr>
#     <th>CHE</th>
#     <th>1106</th>
#     <th>-9.856978</th>
#     <th>-12.353797</th>
#   </tr>
#   <tr>
#     <th>PRK</th>
#     <th>4014</th>
#     <th>-9.377303</th>
#     <th>-10.420216</th>
#   </tr>
#   <tr>
#     <th>MDA</th>
#     <th>6113</th>
#     <th>-12.603487</th>
#     <th>-11.233932</th>
#   </tr>
# </table>

# %%
(learn.get_idx(['FIN', 'NOR', 'CAN'], is_item=False),
 learn.get_idx(['1001', '3215', '3701'], is_item=True))
# Out:
# (tensor([36, 80, 16]), tensor([ 87, 374, 402]))

# %%
learn.model.forward(tensor([36]), tensor([87]))
# Out:
# tensor([-8.4251])

# %%
train_preds, _ = learn.get_preds(ds_type=DatasetType.Train)
train_preds
# Out:
# tensor([ -8.3314, -11.7059,  -9.3993,  ...,  -6.7823, -10.8300,  -8.9736])

# %%
len(train_preds)
# Out:
# 79680

# %% [markdown]
# ## Let's see the biases

# %% [markdown]
# The neural network implementation of a collaborative filtering algorithm in fastai includes some user and item biases. Maybe, these biases can be good candidates to represent the implicit knowhow of countries and complexity of products.

# %%
total_users, total_items = learn.data.classes.values()

# %%
user_idx = learn.get_idx(ctry_names, is_item=False)
item_idx = learn.get_idx(prod_names, is_item=True)

# %%
ctry_biases = learn.bias(ctry_names, is_item=False)
prod_biases = learn.bias(prod_names, is_item=True)

# %%
ctry_biases_dict = [(cn, np.round(cb, 3)) for cn,cb in zip(ctry_names, ctry_biases)]
prod_biases_dict = [(pn, np.round(pb, 3)) for pn,pb in zip(prod_names, prod_biases)]

# %%
item1 = lambda x: x[1]

# %%
sorted(ctry_biases_dict, key=item1)
# Out:
# [('CIV', tensor(-0.2260)),
#  ('PAK', tensor(-0.1990)),
#  ('BGD', tensor(-0.1770)),
#  ('GHA', tensor(-0.1610)),
#  ('GAB', tensor(-0.1520)),
#  ('HND', tensor(-0.1490)),
#  ('DOM', tensor(-0.1460)),
#  ('PNG', tensor(-0.1460)),
#  ('PHL', tensor(-0.1430)),
#  ('CMR', tensor(-0.1420)),
#  ('ECU', tensor(-0.1420)),
#  ('GIN', tensor(-0.1420)),
#  ('MAR', tensor(-0.1390)),
#  ('CRI', tensor(-0.1250)),
#  ('JAM', tensor(-0.1230)),
#  ('LKA', tensor(-0.1120)),
#  ('LBY', tensor(-0.1040)),
#  ('CUB', tensor(-0.1010)),
#  ('PAN', tensor(-0.0960)),
#  ('SLV', tensor(-0.0940)),
#  ('TTO', tensor(-0.0930)),
#  ('GTM', tensor(-0.0910)),
#  ('NGA', tensor(-0.0720)),
#  ('CHL', tensor(-0.0700)),
#  ('SAU', tensor(-0.0700)),
#  ('IRN', tensor(-0.0680)),
#  ('MYS', tensor(-0.0660)),
#  ('VNM', tensor(-0.0660)),
#  ('PER', tensor(-0.0650)),
#  ('OMN', tensor(-0.0630)),
#  ('TUN', tensor(-0.0630)),
#  ('IRL', tensor(-0.0600)),
#  ('NZL', tensor(-0.0580)),
#  ('JPN', tensor(-0.0530)),
#  ('FIN', tensor(-0.0500)),
#  ('PRY', tensor(-0.0480)),
#  ('COG', tensor(-0.0440)),
#  ('COL', tensor(-0.0420)),
#  ('UZB', tensor(-0.0410)),
#  ('IDN', tensor(-0.0310)),
#  ('VEN', tensor(-0.0310)),
#  ('ROU', tensor(-0.0290)),
#  ('UKR', tensor(-0.0260)),
#  ('QAT', tensor(-0.0250)),
#  ('KEN', tensor(-0.0230)),
#  ('THA', tensor(-0.0220)),
#  ('ZWE', tensor(-0.0210)),
#  ('RUS', tensor(-0.0200)),
#  ('KOR', tensor(-0.0180)),
#  ('MDG', tensor(-0.0180)),
#  ('SYR', tensor(-0.0140)),
#  ('NOR', tensor(-0.0130)),
#  ('JOR', tensor(-0.0120)),
#  ('COD', tensor(-0.0110)),
#  ('URY', tensor(-0.0090)),
#  ('ARG', tensor(-0.0070)),
#  ('SVN', tensor(-0.0040)),
#  ('KHM', tensor(-0.0010)),
#  ('MDA', tensor(0.0010)),
#  ('SDN', tensor(0.0030)),
#  ('MEX', tensor(0.0060)),
#  ('NIC', tensor(0.0070)),
#  ('TUR', tensor(0.0100)),
#  ('KWT', tensor(0.0130)),
#  ('BOL', tensor(0.0140)),
#  ('ISR', tensor(0.0180)),
#  ('SGP', tensor(0.0180)),
#  ('PRT', tensor(0.0220)),
#  ('BLR', tensor(0.0240)),
#  ('LBR', tensor(0.0260)),
#  ('BRA', tensor(0.0270)),
#  ('LVA', tensor(0.0290)),
#  ('MKD', tensor(0.0300)),
#  ('CAN', tensor(0.0310)),
#  ('MLI', tensor(0.0310)),
#  ('ARE', tensor(0.0350)),
#  ('DZA', tensor(0.0380)),
#  ('SVK', tensor(0.0400)),
#  ('SWE', tensor(0.0400)),
#  ('ANS', tensor(0.0440)),
#  ('BGR', tensor(0.0440)),
#  ('PRK', tensor(0.0450)),
#  ('HRV', tensor(0.0470)),
#  ('GRC', tensor(0.0530)),
#  ('CHE', tensor(0.0540)),
#  ('EGY', tensor(0.0560)),
#  ('DNK', tensor(0.0610)),
#  ('EST', tensor(0.0660)),
#  ('ZMB', tensor(0.0710)),
#  ('LBN', tensor(0.0720)),
#  ('TJK', tensor(0.0790)),
#  ('HUN', tensor(0.0800)),
#  ('HKG', tensor(0.0820)),
#  ('LTU', tensor(0.0860)),
#  ('AUS', tensor(0.1020)),
#  ('IND', tensor(0.1100)),
#  ('POL', tensor(0.1100)),
#  ('AUT', tensor(0.1160)),
#  ('MOZ', tensor(0.1160)),
#  ('KAZ', tensor(0.1180)),
#  ('CHN', tensor(0.1240)),
#  ('CZE', tensor(0.1510)),
#  ('KGZ', tensor(0.1520)),
#  ('ZAF', tensor(0.1520)),
#  ('ESP', tensor(0.1540)),
#  ('ITA', tensor(0.1540)),
#  ('ALB', tensor(0.1600)),
#  ('BEL', tensor(0.1770)),
#  ('NLD', tensor(0.1780)),
#  ('AGO', tensor(0.1790)),
#  ('DEU', tensor(0.1840)),
#  ('GBR', tensor(0.1860)),
#  ('USA', tensor(0.1930)),
#  ('FRA', tensor(0.2000)),
#  ('AZE', tensor(0.2260)),
#  ('BIH', tensor(0.2540))]

# %%
sorted(prod_biases_dict, key=item1)
# Out:
# [('2705', tensor(-0.4660)),
#  ('8006', tensor(-0.4580)),
#  ('5006', tensor(-0.4170)),
#  ('6602', tensor(-0.4040)),
#  ('9604', tensor(-0.4010)),
#  ('2913', tensor(-0.3930)),
#  ('9204', tensor(-0.3890)),
#  ('0907', tensor(-0.3710)),
#  ('5110', tensor(-0.3690)),
#  ('4815', tensor(-0.3620)),
#  ('8005', tensor(-0.3600)),
#  ('1802', tensor(-0.3510)),
#  ('7417', tensor(-0.3490)),
#  ('0501', tensor(-0.3460)),
#  ('4204', tensor(-0.3460)),
#  ('4502', tensor(-0.3450)),
#  ('5302', tensor(-0.3430)),
#  ('5104', tensor(-0.3420)),
#  ('7805', tensor(-0.3400)),
#  ('7107', tensor(-0.3350)),
#  ('7416', tensor(-0.3340)),
#  ('5605', tensor(-0.3320)),
#  ('2502', tensor(-0.3310)),
#  ('1402', tensor(-0.3300)),
#  ('1903', tensor(-0.3300)),
#  ('1204', tensor(-0.3290)),
#  ('7906', tensor(-0.3290)),
#  ('1505', tensor(-0.3280)),
#  ('5803', tensor(-0.3270)),
#  ('0903', tensor(-0.3260)),
#  ('4904', tensor(-0.3250)),
#  ('5905', tensor(-0.3250)),
#  ('7111', tensor(-0.3220)),
#  ('5113', tensor(-0.3210)),
#  ('6502', tensor(-0.3190)),
#  ('9103', tensor(-0.3160)),
#  ('9104', tensor(-0.3150)),
#  ('6906', tensor(-0.3140)),
#  ('5005', tensor(-0.3120)),
#  ('9614', tensor(-0.3100)),
#  ('5809', tensor(-0.3090)),
#  ('7109', tensor(-0.3090)),
#  ('7012', tensor(-0.3070)),
#  ('9112', tensor(-0.3020)),
#  ('0905', tensor(-0.3000)),
#  ('0502', tensor(-0.2970)),
#  ('2911', tensor(-0.2960)),
#  ('3807', tensor(-0.2960)),
#  ('0509', tensor(-0.2950)),
#  ('6308', tensor(-0.2940)),
#  ('8113', tensor(-0.2940)),
#  ('6507', tensor(-0.2920)),
#  ('9605', tensor(-0.2920)),
#  ('4501', tensor(-0.2910)),
#  ('9702', tensor(-0.2900)),
#  ('3211', tensor(-0.2870)),
#  ('9107', tensor(-0.2860)),
#  ('8002', tensor(-0.2850)),
#  ('9307', tensor(-0.2850)),
#  ('9601', tensor(-0.2800)),
#  ('2845', tensor(-0.2790)),
#  ('8109', tensor(-0.2790)),
#  ('2808', tensor(-0.2780)),
#  ('0209', tensor(-0.2750)),
#  ('0410', tensor(-0.2750)),
#  ('9304', tensor(-0.2730)),
#  ('9611', tensor(-0.2730)),
#  ('6701', tensor(-0.2720)),
#  ('9016', tensor(-0.2720)),
#  ('9203', tensor(-0.2700)),
#  ('4405', tensor(-0.2690)),
#  ('1510', tensor(-0.2680)),
#  ('4416', tensor(-0.2670)),
#  ('7414', tensor(-0.2670)),
#  ('8435', tensor(-0.2670)),
#  ('9610', tensor(-0.2670)),
#  ('2509', tensor(-0.2660)),
#  ('1506', tensor(-0.2640)),
#  ('5910', tensor(-0.2640)),
#  ('8003', tensor(-0.2640)),
#  ('2802', tensor(-0.2630)),
#  ('5805', tensor(-0.2610)),
#  ('0814', tensor(-0.2600)),
#  ('6814', tensor(-0.2600)),
#  ('8304', tensor(-0.2590)),
#  ('4206', tensor(-0.2580)),
#  ('7015', tensor(-0.2580)),
#  ('7609', tensor(-0.2580)),
#  ('7316', tensor(-0.2570)),
#  ('9110', tensor(-0.2550)),
#  ('5901', tensor(-0.2540)),
#  ('9302', tensor(-0.2540)),
#  ('5405', tensor(-0.2530)),
#  ('4822', tensor(-0.2520)),
#  ('5303', tensor(-0.2520)),
#  ('5908', tensor(-0.2520)),
#  ('9618', tensor(-0.2520)),
#  ('1501', tensor(-0.2500)),
#  ('1213', tensor(-0.2490)),
#  ('6501', tensor(-0.2490)),
#  ('6603', tensor(-0.2470)),
#  ('8004', tensor(-0.2470)),
#  ('2838', tensor(-0.2450)),
#  ('5304', tensor(-0.2450)),
#  ('7319', tensor(-0.2450)),
#  ('5001', tensor(-0.2440)),
#  ('6703', tensor(-0.2440)),
#  ('2816', tensor(-0.2430)),
#  ('1522', tensor(-0.2420)),
#  ('7014', tensor(-0.2420)),
#  ('7806', tensor(-0.2420)),
#  ('3704', tensor(-0.2410)),
#  ('3821', tensor(-0.2400)),
#  ('7611', tensor(-0.2390)),
#  ('9109', tensor(-0.2370)),
#  ('2604', tensor(-0.2360)),
#  ('2940', tensor(-0.2360)),
#  ('0906', tensor(-0.2350)),
#  ('5507', tensor(-0.2340)),
#  ('2842', tensor(-0.2320)),
#  ('3407', tensor(-0.2320)),
#  ('5909', tensor(-0.2320)),
#  ('8476', tensor(-0.2320)),
#  ('2813', tensor(-0.2300)),
#  ('2832', tensor(-0.2280)),
#  ('4304', tensor(-0.2280)),
#  ('4503', tensor(-0.2280)),
#  ('8801', tensor(-0.2280)),
#  ('4812', tensor(-0.2270)),
#  ('8213', tensor(-0.2270)),
#  ('6504', tensor(-0.2260)),
#  ('2528', tensor(-0.2250)),
#  ('4905', tensor(-0.2250)),
#  ('8804', tensor(-0.2250)),
#  ('4007', tensor(-0.2230)),
#  ('2513', tensor(-0.2220)),
#  ('2307', tensor(-0.2210)),
#  ('7507', tensor(-0.2210)),
#  ('3803', tensor(-0.2190)),
#  ('8210', tensor(-0.2190)),
#  ('2810', tensor(-0.2170)),
#  ('3213', tensor(-0.2170)),
#  ('2006', tensor(-0.2150)),
#  ('2706', tensor(-0.2150)),
#  ('9202', tensor(-0.2150)),
#  ('2514', tensor(-0.2140)),
#  ('2618', tensor(-0.2140)),
#  ('8510', tensor(-0.2140)),
#  ('5811', tensor(-0.2130)),
#  ('9208', tensor(-0.2130)),
#  ('1105', tensor(-0.2110)),
#  ('6213', tensor(-0.2110)),
#  ('2919', tensor(-0.2100)),
#  ('8007', tensor(-0.2080)),
#  ('3804', tensor(-0.2070)),
#  ('8214', tensor(-0.2070)),
#  ('3502', tensor(-0.2060)),
#  ('4906', tensor(-0.2050)),
#  ('5305', tensor(-0.2030)),
#  ('6503', tensor(-0.2030)),
#  ('9616', tensor(-0.2030)),
#  ('3813', tensor(-0.2020)),
#  ('8449', tensor(-0.2020)),
#  ('9303', tensor(-0.2020)),
#  ('2605', tensor(-0.2010)),
#  ('2305', tensor(-0.2000)),
#  ('3706', tensor(-0.2000)),
#  ('8106', tensor(-0.1990)),
#  ('2831', tensor(-0.1980)),
#  ('2928', tensor(-0.1970)),
#  ('8310', tensor(-0.1970)),
#  ('9501', tensor(-0.1970)),
#  ('0908', tensor(-0.1960)),
#  ('0503', tensor(-0.1950)),
#  ('1203', tensor(-0.1950)),
#  ('2848', tensor(-0.1940)),
#  ('6704', tensor(-0.1940)),
#  ('2812', tensor(-0.1930)),
#  ('4705', tensor(-0.1930)),
#  ('5311', tensor(-0.1930)),
#  ('9206', tensor(-0.1930)),
#  ('3914', tensor(-0.1920)),
#  ('5406', tensor(-0.1920)),
#  ('2525', tensor(-0.1910)),
#  ('1106', tensor(-0.1900)),
#  ('2829', tensor(-0.1900)),
#  ('4003', tensor(-0.1900)),
#  ('6113', tensor(-0.1900)),
#  ('7904', tensor(-0.1900)),
#  ('3820', tensor(-0.1890)),
#  ('2908', tensor(-0.1880)),
#  ('9008', tensor(-0.1880)),
#  ('9106', tensor(-0.1860)),
#  ('2206', tensor(-0.1840)),
#  ('7101', tensor(-0.1840)),
#  ('0408', tensor(-0.1830)),
#  ('3705', tensor(-0.1830)),
#  ('2819', tensor(-0.1820)),
#  ('3601', tensor(-0.1820)),
#  ('5704', tensor(-0.1820)),
#  ('7415', tensor(-0.1820)),
#  ('2824', tensor(-0.1790)),
#  ('7505', tensor(-0.1770)),
#  ('7804', tensor(-0.1770)),
#  ('8444', tensor(-0.1770)),
#  ('0601', tensor(-0.1760)),
#  ('5907', tensor(-0.1760)),
#  ('8601', tensor(-0.1760)),
#  ('1004', tensor(-0.1750)),
#  ('3606', tensor(-0.1750)),
#  ('4017', tensor(-0.1750)),
#  ('8713', tensor(-0.1750)),
#  ('8107', tensor(-0.1740)),
#  ('9020', tensor(-0.1740)),
#  ('1109', tensor(-0.1730)),
#  ('3819', tensor(-0.1730)),
#  ('5002', tensor(-0.1730)),
#  ('8102', tensor(-0.1730)),
#  ('8209', tensor(-0.1730)),
#  ('9301', tensor(-0.1720)),
#  ('9207', tensor(-0.1710)),
#  ('4108', tensor(-0.1700)),
#  ('7221', tensor(-0.1700)),
#  ('6901', tensor(-0.1690)),
#  ('7118', tensor(-0.1690)),
#  ('3205', tensor(-0.1680)),
#  ('1401', tensor(-0.1670)),
#  ('7907', tensor(-0.1670)),
#  ('8805', tensor(-0.1670)),
#  ('0705', tensor(-0.1660)),
#  ('1503', tensor(-0.1660)),
#  ('5310', tensor(-0.1660)),
#  ('5602', tensor(-0.1650)),
#  ('7203', tensor(-0.1650)),
#  ('6905', tensor(-0.1640)),
#  ('1205', tensor(-0.1630)),
#  ('1805', tensor(-0.1630)),
#  ('2938', tensor(-0.1630)),
#  ('7016', tensor(-0.1630)),
#  ('7905', tensor(-0.1630)),
#  ('7803', tensor(-0.1620)),
#  ('2830', tensor(-0.1610)),
#  ('7223', tensor(-0.1590)),
#  ('9402', tensor(-0.1590)),
#  ('6215', tensor(-0.1580)),
#  ('9617', tensor(-0.1580)),
#  ('5904', tensor(-0.1570)),
#  ('8420', tensor(-0.1570)),
#  ('8715', tensor(-0.1570)),
#  ('2923', tensor(-0.1560)),
#  ('7008', tensor(-0.1560)),
#  ('9205', tensor(-0.1560)),
#  ('2843', tensor(-0.1550)),
#  ('4110', tensor(-0.1550)),
#  ('8434', tensor(-0.1550)),
#  ('9011', tensor(-0.1550)),
#  ('4004', tensor(-0.1540)),
#  ('6909', tensor(-0.1540)),
#  ('8307', tensor(-0.1540)),
#  ('2209', tensor(-0.1520)),
#  ('4404', tensor(-0.1520)),
#  ('5609', tensor(-0.1520)),
#  ('5301', tensor(-0.1510)),
#  ('7001', tensor(-0.1510)),
#  ('2927', tensor(-0.1500)),
#  ('4201', tensor(-0.1500)),
#  ('5308', tensor(-0.1500)),
#  ('2703', tensor(-0.1490)),
#  ('2840', tensor(-0.1490)),
#  ('5108', tensor(-0.1490)),
#  ('6808', tensor(-0.1480)),
#  ('7508', tensor(-0.1480)),
#  ('5606', tensor(-0.1470)),
#  ('2205', tensor(-0.1460)),
#  ('7313', tensor(-0.1460)),
#  ('7405', tensor(-0.1460)),
#  ('7903', tensor(-0.1460)),
#  ('3805', tensor(-0.1450)),
#  ('6801', tensor(-0.1450)),
#  ('9114', tensor(-0.1450)),
#  ('2512', tensor(-0.1440)),
#  ('2526', tensor(-0.1440)),
#  ('4903', tensor(-0.1430)),
#  ('5604', tensor(-0.1430)),
#  ('3212', tensor(-0.1420)),
#  ('5109', tensor(-0.1420)),
#  ('1102', tensor(-0.1410)),
#  ('1210', tensor(-0.1410)),
#  ('1508', tensor(-0.1410)),
#  ('5808', tensor(-0.1410)),
#  ('1509', tensor(-0.1400)),
#  ('8206', tensor(-0.1400)),
#  ('4006', tensor(-0.1390)),
#  ('4910', tensor(-0.1380)),
#  ('9012', tensor(-0.1380)),
#  ('9005', tensor(-0.1370)),
#  ('9201', tensor(-0.1370)),
#  ('5003', tensor(-0.1360)),
#  ('5004', tensor(-0.1360)),
#  ('2837', tensor(-0.1340)),
#  ('4908', tensor(-0.1340)),
#  ('0706', tensor(-0.1330)),
#  ('8530', tensor(-0.1320)),
#  ('4111', tensor(-0.1310)),
#  ('4419', tensor(-0.1310)),
#  ('7002', tensor(-0.1310)),
#  ('2850', tensor(-0.1300)),
#  ('5404', tensor(-0.1300)),
#  ('3505', tensor(-0.1290)),
#  ('5307', tensor(-0.1290)),
#  ('8475', tensor(-0.1290)),
#  ('1521', tensor(-0.1280)),
#  ('7504', tensor(-0.1280)),
#  ('0206', tensor(-0.1270)),
#  ('2925', tensor(-0.1270)),
#  ('8103', tensor(-0.1270)),
#  ('8404', tensor(-0.1270)),
#  ('1518', tensor(-0.1260)),
#  ('2521', tensor(-0.1260)),
#  ('2847', tensor(-0.1260)),
#  ('3504', tensor(-0.1260)),
#  ('7613', tensor(-0.1260)),
#  ('1803', tensor(-0.1250)),
#  ('2821', tensor(-0.1250)),
#  ('6803', tensor(-0.1250)),
#  ('9704', tensor(-0.1250)),
#  ('4807', tensor(-0.1240)),
#  ('8111', tensor(-0.1240)),
#  ('8204', tensor(-0.1240)),
#  ('9105', tensor(-0.1240)),
#  ('8907', tensor(-0.1230)),
#  ('4504', tensor(-0.1220)),
#  ('4701', tensor(-0.1220)),
#  ('0707', tensor(-0.1210)),
#  ('2806', tensor(-0.1210)),
#  ('4601', tensor(-0.1210)),
#  ('5511', tensor(-0.1210)),
#  ('6903', tensor(-0.1210)),
#  ('1214', tensor(-0.1200)),
#  ('2826', tensor(-0.1200)),
#  ('6809', tensor(-0.1190)),
#  ('7017', tensor(-0.1190)),
#  ('8906', tensor(-0.1190)),
#  ('2910', tensor(-0.1180)),
#  ('7020', tensor(-0.1180)),
#  ('0404', tensor(-0.1170)),
#  ('3404', tensor(-0.1170)),
#  ('3816', tensor(-0.1170)),
#  ('9305', tensor(-0.1160)),
#  ('1002', tensor(-0.1150)),
#  ('6310', tensor(-0.1150)),
#  ('7004', tensor(-0.1150)),
#  ('7116', tensor(-0.1150)),
#  ('8416', tensor(-0.1150)),
#  ('2614', tensor(-0.1140)),
#  ('5807', tensor(-0.1140)),
#  ('8464', tensor(-0.1140)),
#  ('8608', tensor(-0.1140)),
#  ('0704', tensor(-0.1130)),
#  ('2817', tensor(-0.1130)),
#  ('4816', tensor(-0.1130)),
#  ('7006', tensor(-0.1130)),
#  ('9111', tensor(-0.1130)),
#  ('9613', tensor(-0.1130)),
#  ('2619', tensor(-0.1120)),
#  ('2846', tensor(-0.1120)),
#  ('2942', tensor(-0.1120)),
#  ('7412', tensor(-0.1120)),
#  ('8469', tensor(-0.1120)),
#  ('2522', tensor(-0.1100)),
#  ('3810', tensor(-0.1090)),
#  ('7220', tensor(-0.1090)),
#  ('2714', tensor(-0.1080)),
#  ('2805', tensor(-0.1080)),
#  ('4417', tensor(-0.1080)),
#  ('7011', tensor(-0.1080)),
#  ('8401', tensor(-0.1080)),
#  ('8410', tensor(-0.1080)),
#  ('8468', tensor(-0.1070)),
#  ('9108', tensor(-0.1070)),
#  ('9602', tensor(-0.1070)),
#  ('3916', tensor(-0.1060)),
#  ('5508', tensor(-0.1060)),
#  ('1007', tensor(-0.1050)),
#  ('3910', tensor(-0.1050)),
#  ('7018', tensor(-0.1050)),
#  ('7506', tensor(-0.1040)),
#  ('9025', tensor(-0.1040)),
#  ('5103', tensor(-0.1030)),
#  ('6216', tensor(-0.1030)),
#  ('9508', tensor(-0.1030)),
#  ('5906', tensor(-0.1010)),
#  ('7418', tensor(-0.1010)),
#  ('4414', tensor(-0.1000)),
#  ('4806', tensor(-0.1000)),
#  ('4014', tensor(-0.0990)),
#  ('4413', tensor(-0.0990)),
#  ('9113', tensor(-0.0990)),
#  ('2518', tensor(-0.0980)),
#  ('4909', tensor(-0.0980)),
#  ('6904', tensor(-0.0980)),
#  ('8478', tensor(-0.0980)),
#  ('0507', tensor(-0.0970)),
#  ('0909', tensor(-0.0970)),
#  ('2906', tensor(-0.0970)),
#  ('5705', tensor(-0.0970)),
#  ('6702', tensor(-0.0970)),
#  ('7226', tensor(-0.0970)),
#  ('8453', tensor(-0.0970)),
#  ('8605', tensor(-0.0970)),
#  ('2820', tensor(-0.0960)),
#  ('4301', tensor(-0.0960)),
#  ('0714', tensor(-0.0950)),
#  ('0812', tensor(-0.0950)),
#  ('2851', tensor(-0.0950)),
#  ('3203', tensor(-0.0940)),
#  ('8603', tensor(-0.0940)),
#  ('9002', tensor(-0.0940)),
#  ('0205', tensor(-0.0930)),
#  ('0208', tensor(-0.0930)),
#  ('2308', tensor(-0.0930)),
#  ('0210', tensor(-0.0910)),
#  ('3210', tensor(-0.0910)),
#  ('8208', tensor(-0.0910)),
#  ('9209', tensor(-0.0910)),
#  ('2510', tensor(-0.0900)),
#  ('8305', tensor(-0.0900)),
#  ('8203', tensor(-0.0890)),
#  ('8440', tensor(-0.0890)),
#  ('3201', tensor(-0.0880)),
#  ('5502', tensor(-0.0880)),
#  ('8513', tensor(-0.0880)),
#  ('0510', tensor(-0.0870)),
#  ('2004', tensor(-0.0870)),
#  ('2511', tensor(-0.0870)),
#  ('3604', tensor(-0.0870)),
#  ('8519', tensor(-0.0870)),
#  ('3818', tensor(-0.0860)),
#  ('8110', tensor(-0.0860)),
#  ('8908', tensor(-0.0860)),
#  ('8456', tensor(-0.0850)),
#  ('0409', tensor(-0.0840)),
#  ('7114', tensor(-0.0840)),
#  ('9019', tensor(-0.0840)),
#  ('3801', tensor(-0.0830)),
#  ('8303', tensor(-0.0830)),
#  ('9029', tensor(-0.0830)),
#  ('3202', tensor(-0.0820)),
#  ('3802', tensor(-0.0820)),
#  ('9004', tensor(-0.0820)),
#  ('0506', tensor(-0.0810)),
#  ('1603', tensor(-0.0810)),
#  ('6805', tensor(-0.0810)),
#  ('4814', tensor(-0.0800)),
#  ('1504', tensor(-0.0790)),
#  ('2822', tensor(-0.0790)),
#  ('6812', tensor(-0.0790)),
#  ('8211', tensor(-0.0790)),
#  ('4809', tensor(-0.0780)),
#  ('7413', tensor(-0.0780)),
#  ('8202', tensor(-0.0780)),
#  ('8604', tensor(-0.0780)),
#  ('2621', tensor(-0.0770)),
#  ('5810', tensor(-0.0770)),
#  ('7205', tensor(-0.0770)),
#  ('7406', tensor(-0.0760)),
#  ('9010', tensor(-0.0760)),
#  ('2507', tensor(-0.0750)),
#  ('7104', tensor(-0.0750)),
#  ('6506', tensor(-0.0740)),
#  ('7224', tensor(-0.0740)),
#  ('2506', tensor(-0.0730)),
#  ('1502', tensor(-0.0720)),
#  ('4415', tensor(-0.0710)),
#  ('7501', tensor(-0.0710)),
#  ('2827', tensor(-0.0700)),
#  ('3811', tensor(-0.0700)),
#  ('2937', tensor(-0.0690)),
#  ('3403', tensor(-0.0690)),
#  ('8403', tensor(-0.0690)),
#  ('7301', tensor(-0.0680)),
#  ('2828', tensor(-0.0670)),
#  ('4813', tensor(-0.0670)),
#  ('3603', tensor(-0.0660)),
#  ('5902', tensor(-0.0660)),
#  ('6601', tensor(-0.0660)),
#  ('8104', tensor(-0.0660)),
#  ('3406', tensor(-0.0650)),
#  ('6807', tensor(-0.0650)),
#  ('7003', tensor(-0.0650)),
#  ('8547', tensor(-0.0650)),
#  ('2105', tensor(-0.0640)),
#  ('5306', tensor(-0.0640)),
#  ('7902', tensor(-0.0640)),
#  ('4406', tensor(-0.0630)),
#  ('7105', tensor(-0.0630)),
#  ('7115', tensor(-0.0630)),
#  ('7303', tensor(-0.0630)),
#  ('8405', tensor(-0.0630)),
#  ('8454', tensor(-0.0630)),
#  ('3207', tensor(-0.0620)),
#  ('3911', tensor(-0.0620)),
#  ('5106', tensor(-0.0620)),
#  ('8215', tensor(-0.0620)),
#  ('8467', tensor(-0.0620)),
#  ('8602', tensor(-0.0610)),
#  ('9609', tensor(-0.0610)),
#  ('6907', tensor(-0.0600)),
#  ('8545', tensor(-0.0600)),
#  ('0505', tensor(-0.0590)),
#  ('9615', tensor(-0.0590)),
#  ('5804', tensor(-0.0580)),
#  ('7401', tensor(-0.0580)),
#  ('8201', tensor(-0.0580)),
#  ('0403', tensor(-0.0570)),
#  ('2303', tensor(-0.0570)),
#  ('5802', tensor(-0.0570)),
#  ('7802', tensor(-0.0570)),
#  ('8455', tensor(-0.0570)),
#  ('4602', tensor(-0.0560)),
#  ('7603', tensor(-0.0560)),
#  ('9703', tensor(-0.0560)),
#  ('2839', tensor(-0.0550)),
#  ('0103', tensor(-0.0540)),
#  ('2505', tensor(-0.0540)),
#  ('2801', tensor(-0.0540)),
#  ('2844', tensor(-0.0540)),
#  ('6303', tensor(-0.0540)),
#  ('6309', tensor(-0.0540)),
#  ('8546', tensor(-0.0540)),
#  ('9612', tensor(-0.0540)),
#  ('1008', tensor(-0.0530)),
#  ('1103', tensor(-0.0530)),
#  ('2803', tensor(-0.0530)),
#  ('2904', tensor(-0.0530)),
#  ('7218', tensor(-0.0530)),
#  ('8101', tensor(-0.0530)),
#  ('8514', tensor(-0.0530)),
#  ('9023', tensor(-0.0530)),
#  ('9705', tensor(-0.0530)),
#  ('2529', tensor(-0.0520)),
#  ('7410', tensor(-0.0520)),
#  ('8707', tensor(-0.0520)),
#  ('2003', tensor(-0.0500)),
#  ('2519', tensor(-0.0500)),
#  ('2920', tensor(-0.0500)),
#  ('3101', tensor(-0.0500)),
#  ('9017', tensor(-0.0500)),
#  ('2841', tensor(-0.0490)),
#  ('4009', tensor(-0.0490)),
#  ('2834', tensor(-0.0480)),
#  ('6914', tensor(-0.0480)),
#  ('7503', tensor(-0.0480)),
#  ('7608', tensor(-0.0480)),
#  ('2611', tensor(-0.0470)),
#  ('5401', tensor(-0.0470)),
#  ('5911', tensor(-0.0470)),
#  ('8606', tensor(-0.0470)),
#  ('2702', tensor(-0.0460)),
#  ('3001', tensor(-0.0460)),
#  ('4817', tensor(-0.0460)),
#  ('7229', tensor(-0.0460)),
#  ('2201', tensor(-0.0450)),
#  ('8520', tensor(-0.0450)),
#  ('8709', tensor(-0.0450)),
#  ('1208', tensor(-0.0440)),
#  ('3814', tensor(-0.0440)),
#  ('8484', tensor(-0.0440)),
#  ('9033', tensor(-0.0440)),
#  ('0604', tensor(-0.0430)),
#  ('2929', tensor(-0.0430)),
#  ('2907', tensor(-0.0420)),
#  ('2931', tensor(-0.0420)),
#  ('8112', tensor(-0.0420)),
#  ('2530', tensor(-0.0410)),
#  ('5204', tensor(-0.0410)),
#  ('5608', tensor(-0.0410)),
#  ('8533', tensor(-0.0410)),
#  ('8710', tensor(-0.0410)),
#  ('1104', tensor(-0.0400)),
#  ('2939', tensor(-0.0390)),
#  ('2912', tensor(-0.0380)),
#  ('5207', tensor(-0.0380)),
#  ('5212', tensor(-0.0380)),
#  ('8442', tensor(-0.0380)),
#  ('2504', tensor(-0.0370)),
#  ('3605', tensor(-0.0370)),
#  ('4402', tensor(-0.0370)),
#  ('0806', tensor(-0.0360)),
#  ('8306', tensor(-0.0360)),
#  ('8108', tensor(-0.0340)),
#  ('3707', tensor(-0.0330)),
#  ('4008', tensor(-0.0330)),
#  ('8308', tensor(-0.0330)),
#  ('2515', tensor(-0.0320)),
#  ('2617', tensor(-0.0320)),
#  ('3507', tensor(-0.0320)),
#  ('9505', tensor(-0.0320)),
#  ('5504', tensor(-0.0310)),
#  ('6804', tensor(-0.0310)),
#  ('6815', tensor(-0.0310)),
#  ('8311', tensor(-0.0300)),
#  ('0104', tensor(-0.0290)),
#  ('2508', tensor(-0.0290)),
#  ('8457', tensor(-0.0290)),
#  ('0101', tensor(-0.0280)),
#  ('0809', tensor(-0.0280)),
#  ('7227', tensor(-0.0280)),
#  ('9024', tensor(-0.0280)),
#  ('1601', tensor(-0.0270)),
#  ('3822', tensor(-0.0270)),
#  ('3912', tensor(-0.0270)),
#  ('5505', tensor(-0.0270)),
#  ('9607', tensor(-0.0270)),
#  ('3215', tensor(-0.0250)),
#  ('9101', tensor(-0.0250)),
#  ('0702', tensor(-0.0240)),
#  ('2823', tensor(-0.0240)),
#  ('8463', tensor(-0.0240)),
#  ('3703', tensor(-0.0230)),
#  ('4205', tensor(-0.0230)),
#  ('8461', tensor(-0.0230)),
#  ('2809', tensor(-0.0220)),
#  ('4803', tensor(-0.0220)),
#  ('5701', tensor(-0.0220)),
#  ('9003', tensor(-0.0220)),
#  ('0813', tensor(-0.0210)),
#  ('2935', tensor(-0.0210)),
#  ('3503', tensor(-0.0200)),
#  ('2524', tensor(-0.0190)),
#  ('8309', tensor(-0.0190)),
#  ('6304', tensor(-0.0180)),
#  ('9013', tensor(-0.0180)),
#  ('3701', tensor(-0.0170)),
#  ('4303', tensor(-0.0170)),
#  ('4702', tensor(-0.0170)),
#  ('5510', tensor(-0.0170)),
#  ('7009', tensor(-0.0170)),
#  ('8450', tensor(-0.0170)),
#  ('3922', tensor(-0.0160)),
#  ('6813', tensor(-0.0160)),
#  ('8460', tensor(-0.0160)),
#  ('0401', tensor(-0.0150)),
#  ('1516', tensor(-0.0150)),
#  ('7322', tensor(-0.0150)),
#  ('3806', tensor(-0.0140)),
#  ('3905', tensor(-0.0130)),
#  ('4907', tensor(-0.0130)),
#  ('5007', tensor(-0.0130)),
#  ('2102', tensor(-0.0120)),
#  ('3103', tensor(-0.0120)),
#  ('8446', tensor(-0.0120)),
#  ('0105', tensor(-0.0110)),
#  ('3909', tensor(-0.0110)),
#  ('8609', tensor(-0.0110)),
#  ('9502', tensor(-0.0110)),
#  ('9606', tensor(-0.0110)),
#  ('7324', tensor(-0.0100)),
#  ('1206', tensor(-0.0090)),
#  ('2503', tensor(-0.0090)),
#  ('7312', tensor(-0.0090)),
#  ('8212', tensor(-0.0090)),
#  ('5309', tensor(-0.0080)),
#  ('2708', tensor(-0.0070)),
#  ('6806', tensor(-0.0070)),
#  ('3908', tensor(-0.0060)),
#  ('5806', tensor(-0.0060)),
#  ('6101', tensor(-0.0060)),
#  ('1514', tensor(-0.0050)),
#  ('3405', tensor(-0.0050)),
#  ('7302', tensor(-0.0050)),
#  ('9001', tensor(-0.0050)),
#  ('4706', tensor(-0.0040)),
#  ('6102', tensor(-0.0040)),
#  ('7206', tensor(-0.0040)),
#  ('7222', tensor(-0.0040)),
#  ('9007', tensor(-0.0040)),
#  ('1702', tensor(-0.0030)),
#  ('2914', tensor(-0.0030)),
#  ('8470', tensor(-0.0030)),
#  ('0203', tensor(-0.0020)),
#  ('2616', tensor(-0.0020)),
#  ('5102', tensor(-0.0010)),
#  ('7320', tensor(-0.0010)),
#  ('9507', tensor(-0.0010)),
#  ('3006', tensor(0.)),
#  ('6911', tensor(0.)),
#  ('8505', tensor(-0.)),
#  ('2924', tensor(0.0010)),
#  ('4302', tensor(0.0010)),
#  ('2849', tensor(0.0020)),
#  ('1107', tensor(0.0040)),
#  ('8423', tensor(0.0040)),
#  ('3602', tensor(0.0050)),
#  ('3812', tensor(0.0050)),
#  ('2613', tensor(0.0060)),
#  ('7614', tensor(0.0060)),
#  ('0508', tensor(0.0070)),
#  ('4109', tensor(0.0070)),
#  ('5506', tensor(0.0070)),
#  ('8472', tensor(0.0070)),
#  ('3501', tensor(0.0080)),
#  ('4005', tensor(0.0080)),
#  ('4013', tensor(0.0090)),
#  ('7215', tensor(0.0090)),
#  ('2609', tensor(0.0100)),
#  ('2615', tensor(0.0100)),
#  ('8522', tensor(0.0100)),
#  ('2403', tensor(0.0110)),
#  ('2934', tensor(0.0120)),
#  ('6912', tensor(0.0120)),
#  ('1108', tensor(0.0150)),
#  ('3809', tensor(0.0150)),
#  ('4010', tensor(0.0160)),
#  ('8437', tensor(0.0160)),
#  ('0405', tensor(0.0180)),
#  ('3702', tensor(0.0180)),
#  ('3918', tensor(0.0180)),
#  ('4401', tensor(0.0180)),
#  ('6116', tensor(0.0190)),
#  ('7228', tensor(0.0190)),
#  ('8711', tensor(0.0190)),
#  ('2712', tensor(0.0200)),
#  ('0511', tensor(0.0210)),
#  ('2602', tensor(0.0210)),
#  ('8535', tensor(0.0230)),
#  ('2517', tensor(0.0250)),
#  ('6505', tensor(0.0250)),
#  ('9021', tensor(0.0250)),
#  ('5514', tensor(0.0260)),
#  ('7309', tensor(0.0260)),
#  ('8402', tensor(0.0260)),
#  ('2921', tensor(0.0270)),
#  ('3214', tensor(0.0270)),
#  ('6214', tensor(0.0270)),
#  ('7615', tensor(0.0270)),
#  ('8904', tensor(0.0270)),
#  ('0904', tensor(0.0280)),
#  ('1202', tensor(0.0280)),
#  ('3925', tensor(0.0300)),
#  ('8458', tensor(0.0300)),
#  ('8508', tensor(0.0300)),
#  ('4808', tensor(0.0310)),
#  ('6117', tensor(0.0310)),
#  ('8903', tensor(0.0310)),
#  ('7605', tensor(0.0320)),
#  ('8406', tensor(0.0320)),
#  ('1301', tensor(0.0350)),
#  ('3817', tensor(0.0350)),
#  ('5111', tensor(0.0350)),
#  ('2520', tensor(0.0360)),
#  ('0204', tensor(0.0370)),
#  ('0602', tensor(0.0370)),
#  ('0801', tensor(0.0370)),
#  ('4015', tensor(0.0370)),
#  ('8607', tensor(0.0370)),
#  ('1904', tensor(0.0380)),
#  ('2007', tensor(0.0380)),
#  ('2807', tensor(0.0380)),
#  ('2818', tensor(0.0380)),
#  ('5403', tensor(0.0380)),
#  ('7007', tensor(0.0380)),
#  ('3913', tensor(0.0390)),
#  ('4821', tensor(0.0390)),
#  ('6401', tensor(0.0400)),
#  ('7419', tensor(0.0400)),
#  ('2001', tensor(0.0410)),
#  ('2825', tensor(0.0410)),
#  ('6001', tensor(0.0410)),
#  ('6301', tensor(0.0410)),
#  ('7315', tensor(0.0410)),
#  ('8441', tensor(0.0410)),
#  ('8526', tensor(0.0410)),
#  ('2932', tensor(0.0420)),
#  ('5107', tensor(0.0420)),
#  ('5203', tensor(0.0420)),
#  ('5206', tensor(0.0420)),
#  ('5603', tensor(0.0420)),
#  ('7409', tensor(0.0420)),
#  ('8548', tensor(0.0420)),
#  ('3906', tensor(0.0430)),
#  ('1513', tensor(0.0440)),
#  ('0708', tensor(0.0460)),
#  ('0711', tensor(0.0460)),
#  ('2926', tensor(0.0460)),
#  ('8512', tensor(0.0460)),
#  ('0712', tensor(0.0470)),
#  ('6306', tensor(0.0470)),
#  ('1404', tensor(0.0480)),
#  ('7317', tensor(0.0480)),
#  ('5211', tensor(0.0490)),
#  ('0603', tensor(0.0500)),
#  ('4012', tensor(0.0500)),
#  ('6811', tensor(0.0500)),
#  ('8521', tensor(0.0500)),
#  ('8905', tensor(0.0500)),
#  ('2304', tensor(0.0510)),
#  ('2916', tensor(0.0510)),
#  ('2002', tensor(0.0520)),
#  ('8001', tensor(0.0520)),
#  ('8451', tensor(0.0520)),
#  ('8509', tensor(0.0520)),
#  ('8706', tensor(0.0520)),
#  ('9028', tensor(0.0520)),
#  ('2516', tensor(0.0530)),
#  ('2930', tensor(0.0530)),
#  ('6810', tensor(0.0530)),
#  ('8523', tensor(0.0540)),
#  ('7612', tensor(0.0550)),
#  ('8417', tensor(0.0550)),
#  ('9022', tensor(0.0560)),
#  ('9102', tensor(0.0560)),
#  ('0807', tensor(0.0570)),
#  ('2610', tensor(0.0570)),
#  ('3915', tensor(0.0570)),
#  ('8448', tensor(0.0570)),
#  ('2606', tensor(0.0590)),
#  ('5112', tensor(0.0610)),
#  ('3815', tensor(0.0620)),
#  ('6217', tensor(0.0620)),
#  ('8412', tensor(0.0630)),
#  ('0301', tensor(0.0640)),
#  ('2909', tensor(0.0640)),
#  ('8436', tensor(0.0640)),
#  ('1519', tensor(0.0650)),
#  ('8531', tensor(0.0650)),
#  ('9009', tensor(0.0650)),
#  ('2302', tensor(0.0660)),
#  ('8485', tensor(0.0660)),
#  ('5501', tensor(0.0670)),
#  ('5210', tensor(0.0680)),
#  ('4410', tensor(0.0690)),
#  ('8301', tensor(0.0700)),
#  ('8427', tensor(0.0700)),
#  ('6902', tensor(0.0710)),
#  ('7314', tensor(0.0710)),
#  ('7321', tensor(0.0710)),
#  ('8532', tensor(0.0710)),
#  ('8712', tensor(0.0710)),
#  ('3506', tensor(0.0730)),
#  ('5801', tensor(0.0730)),
#  ('7117', tensor(0.0730)),
#  ('7305', tensor(0.0730)),
#  ('9701', tensor(0.0730)),
#  ('0406', tensor(0.0740)),
#  ('7005', tensor(0.0740)),
#  ('8902', tensor(0.0750)),
#  ('0810', tensor(0.0760)),
#  ('6913', tensor(0.0760)),
#  ('7201', tensor(0.0760)),
#  ('0811', tensor(0.0770)),
#  ('9006', tensor(0.0770)),
#  ('9306', tensor(0.0770)),
#  ('1201', tensor(0.0790)),
#  ('1212', tensor(0.0790)),
#  ('2501', tensor(0.0790)),
#  ('0407', tensor(0.0800)),
#  ('0710', tensor(0.0800)),
#  ('3209', tensor(0.0800)),
#  ('8445', tensor(0.0800)),
#  ('8447', tensor(0.0800)),
#  ('2707', tensor(0.0810)),
#  ('3306', tensor(0.0810)),
#  ('7212', tensor(0.0810)),
#  ('8433', tensor(0.0810)),
#  ('8459', tensor(0.0810)),
#  ('8439', tensor(0.0820)),
#  ('7801', tensor(0.0830)),
#  ('8432', tensor(0.0830)),
#  ('8714', tensor(0.0840)),
#  ('2104', tensor(0.0850)),
#  ('2301', tensor(0.0850)),
#  ('2936', tensor(0.0860)),
#  ('3919', tensor(0.0860)),
#  ('8452', tensor(0.0860)),
#  ('5607', tensor(0.0870)),
#  ('1520', tensor(0.0880)),
#  ('7411', tensor(0.0880)),
#  ('1515', tensor(0.0890)),
#  ('5512', tensor(0.0890)),
#  ('7225', tensor(0.0890)),
#  ('2811', tensor(0.0910)),
#  ('9706', tensor(0.0910)),
#  ('3206', tensor(0.0920)),
#  ('0504', tensor(0.0930)),
#  ('4420', tensor(0.0930)),
#  ('4704', tensor(0.0940)),
#  ('9026', tensor(0.0940)),
#  ('0808', tensor(0.0950)),
#  ('1517', tensor(0.0950)),
#  ('5703', tensor(0.0950)),
#  ('8205', tensor(0.0950)),
#  ('8466', tensor(0.0950)),
#  ('2833', tensor(0.0960)),
#  ('3302', tensor(0.0970)),
#  ('0910', tensor(0.0980)),
#  ('4801', tensor(0.0980)),
#  ('5105', tensor(0.0980)),
#  ('7211', tensor(0.0980)),
#  ('1101', tensor(0.0990)),
#  ('8503', tensor(0.0990)),
#  ('1605', tensor(0.1010)),
#  ('8538', tensor(0.1010)),
#  ('2815', tensor(0.1030)),
#  ('2903', tensor(0.1030)),
#  ('3903', tensor(0.1040)),
#  ('6114', tensor(0.1040)),
#  ('6210', tensor(0.1050)),
#  ('7311', tensor(0.1050)),
#  ('0106', tensor(0.1060)),
#  ('3303', tensor(0.1060)),
#  ('7325', tensor(0.1060)),
#  ('8511', tensor(0.1060)),
#  ('0703', tensor(0.1070)),
#  ('5408', tensor(0.1070)),
#  ('8515', tensor(0.1080)),
#  ('3002', tensor(0.1090)),
#  ('4411', tensor(0.1090)),
#  ('8425', tensor(0.1090)),
#  ('8534', tensor(0.1100)),
#  ('1511', tensor(0.1110)),
#  ('7307', tensor(0.1110)),
#  ('1003', tensor(0.1120)),
#  ('9032', tensor(0.1120)),
#  ('2101', tensor(0.1130)),
#  ('7013', tensor(0.1130)),
#  ('9608', tensor(0.1130)),
#  ('2918', tensor(0.1140)),
#  ('4902', tensor(0.1140)),
#  ('5702', tensor(0.1140)),
#  ('0701', tensor(0.1150)),
#  ('2915', tensor(0.1150)),
#  ('2835', tensor(0.1160)),
#  ('4911', tensor(0.1170)),
#  ('1512', tensor(0.1180)),
#  ('2306', tensor(0.1190)),
#  ('5903', tensor(0.1190)),
#  ('7323', tensor(0.1190)),
#  ('9027', tensor(0.1190)),
#  ('9014', tensor(0.1200)),
#  ('0902', tensor(0.1210)),
#  ('2704', tensor(0.1210)),
#  ('3305', tensor(0.1210)),
#  ('5601', tensor(0.1210)),
#  ('7019', tensor(0.1210)),
#  ('7502', tensor(0.1210)),
#  ('8502', tensor(0.1210)),
#  ('1901', tensor(0.1220)),
#  ('8443', tensor(0.1230)),
#  ('0102', tensor(0.1240)),
#  ('3005', tensor(0.1290)),
#  ('8465', tensor(0.1290)),
#  ('2922', tensor(0.1310)),
#  ('7407', tensor(0.1310)),
#  ('1209', tensor(0.1320)),
#  ('4804', tensor(0.1330)),
#  ('4820', tensor(0.1330)),
#  ('9504', tensor(0.1340)),
#  ('2901', tensor(0.1370)),
#  ('4107', tensor(0.1370)),
#  ('1302', tensor(0.1380)),
#  ('1804', tensor(0.1380)),
#  ('6908', tensor(0.1380)),
#  ('8540', tensor(0.1380)),
#  ('7610', tensor(0.1400)),
#  ('1602', tensor(0.1430)),
#  ('0804', tensor(0.1440)),
#  ('3204', tensor(0.1440)),
#  ('2620', tensor(0.1450)),
#  ('5202', tensor(0.1450)),
#  ('8302', tensor(0.1470)),
#  ('8482', tensor(0.1470)),
#  ('1801', tensor(0.1480)),
#  ('8506', tensor(0.1480)),
#  ('6910', tensor(0.1490)),
#  ('6207', tensor(0.1500)),
#  ('8543', tensor(0.1500)),
#  ('7217', tensor(0.1520)),
#  ('2204', tensor(0.1530)),
#  ('4106', tensor(0.1530)),
#  ('8537', tensor(0.1530)),
#  ('9406', tensor(0.1530)),
#  ('1507', tensor(0.1540)),
#  ('2804', tensor(0.1540)),
#  ('7408', tensor(0.1570)),
#  ('7607', tensor(0.1570)),
#  ('8462', tensor(0.1570)),
#  ('2941', tensor(0.1590)),
#  ('8518', tensor(0.1590)),
#  ('7103', tensor(0.1600)),
#  ('0803', tensor(0.1610)),
#  ('2836', tensor(0.1610)),
#  ('9031', tensor(0.1620)),
#  ('0802', tensor(0.1630)),
#  ('3104', tensor(0.1630)),
#  ('6307', tensor(0.1630)),
#  ('7310', tensor(0.1630)),
#  ('8541', tensor(0.1630)),
#  ('8424', tensor(0.1640)),
#  ('8438', tensor(0.1640)),
#  ...]

# %% [markdown]
# ### Let's check the embeddings

# %%
ctry_weights = learn.weight(ctry_names, is_item=False)
prod_weights = learn.weight(prod_names, is_item=True)
(ctry_weights.shape, prod_weights.shape)
# Out:
# (torch.Size([116, 25]), torch.Size([1221, 25]))

# %%
# To visualize, let's apply PCA or Spectral Embeddings
ctry_wpca = ctry_weights.pca(2)
prod_wpca = prod_weights.pca(2)
(ctry_wpca.shape, prod_wpca.shape)
# Out:
# (torch.Size([116, 2]), torch.Size([1221, 2]))

# %%
fig = plt.figure(figsize=(16,8))

plt.subplot(1, 2, 1)
plt.scatter(ctry_wpca[:,0], ctry_wpca[:,1], alpha=0.2)
plt.xlabel("PC0")
plt.ylabel("PC1")
plt.title("Countries")
for i, txt in enumerate(ctry_names):
    plt.annotate(txt, (ctry_wpca[i,0], ctry_wpca[i,1]), 
                 alpha=(ctry_biases[i].item() - ctry_biases.min().item())/(ctry_biases.max().item()-ctry_biases.min().item()))

plt.subplot(1, 2, 2)
plt.scatter(prod_wpca[:,0], prod_wpca[:,1],
            #alpha=(prod_biases.numpy() - prod_biases.min().item())/(prod_biases.max().item()-prod_biases.min().item()),
            alpha = 0.3)
plt.xlabel("PC0")
plt.ylabel("PC1")
plt.title("Products")

plt.show()

# %%
(prod_biases.numpy() - prod_biases.min().item())/(prod_biases.max().item()-prod_biases.min().item())
# Out:
# array([0.397329, 0.535413, 0.373883, 0.396212, ..., 0.371541, 0.309134, 0.374613, 0.504904], dtype=float32)

# %% [markdown]
# # Checking the predictions applied to 2015

# %% [markdown]
# The model we have just trained is cross-sectional. However, we are interested in assessing whether such model can predict changes in the export baskets of countries.
#
# We can play with the following ideas:
# 1. We can simply check whether the same values are stable in time. That is, simply compare the values predicted for the training year with the values of next year.
# 2. We can generate the predictions for the training year, check the differences with the real values, and assess whether these differences predict the _change_ from the training year to next.
# 3. We can generate the predictions for the missing exports in the training year, and assess whether those top predictions appeared in the next year.

# %% [markdown]
# ### However, let's compare the real in training numbers with those of real in next year

# %%
widedf = collab_df.pivot_table(index=[user_col, item_col], columns='year').reset_index()
widedf.ends(2)
# Out:
#        location_code hs_product_code     ln_Xcp                        \
# year                                       1995       1996       1997
# 0                AGO            0101        NaN        NaN   8.520189
# 1                AGO            0102        NaN        NaN   9.416460
# 136895           ZWE            9705  14.622040  13.699506  13.448133
# 136896           ZWE            9706   9.547098   9.203014  10.535185
#
#                                                                ...  \
# year         1998       1999       2000       2001       2002  ...
# 0             NaN        NaN        NaN        NaN        NaN  ...
# 1             NaN        NaN  12.485283  13.003638  10.856457  ...
# 136895  13.852829  13.956676  14.413279  13.648790  15.719142  ...
# 136896   7.512071        NaN   4.691348  12.712776   9.699840  ...
#
#        mln_mln_share                                                    \
# year            2007      2008      2009      2010      2011      2012
# 0                NaN -2.431773       NaN       NaN       NaN       NaN
# 1          -2.464557       NaN       NaN -2.644796       NaN       NaN
# 136895     -1.955951 -1.782856 -1.819310 -1.681701 -1.938294 -1.991810
# 136896           NaN -2.593016 -2.656962       NaN -2.509978 -2.487586
#
#
# year        2013      2014      2015      2016
# 0            NaN -2.700872       NaN       NaN
# 1      -2.637250       NaN -2.554711       NaN
# 136895 -2.022657 -1.857286 -1.906872 -1.988397
# 136896 -2.551439       NaN -2.554724       NaN
#
# [4 rows x 68 columns]

# %%
newcolumns = ['%s%s' % (a, '_%s' % b if b else '') for a, b in widedf.columns]
widedf.columns = newcolumns
widedf.ends(2)
# Out:
#        location_code hs_product_code  ln_Xcp_1995  ln_Xcp_1996  ln_Xcp_1997  \
# 0                AGO            0101          NaN          NaN     8.520189
# 1                AGO            0102          NaN          NaN     9.416460
# 136895           ZWE            9705    14.622040    13.699506    13.448133
# 136896           ZWE            9706     9.547098     9.203014    10.535185
#
#         ln_Xcp_1998  ln_Xcp_1999  ln_Xcp_2000  ln_Xcp_2001  ln_Xcp_2002  ...  \
# 0               NaN          NaN          NaN          NaN          NaN  ...
# 1               NaN          NaN    12.485283    13.003638    10.856457  ...
# 136895    13.852829    13.956676    14.413279    13.648790    15.719142  ...
# 136896     7.512071          NaN     4.691348    12.712776     9.699840  ...
#
#         mln_mln_share_2007  mln_mln_share_2008  mln_mln_share_2009  \
# 0                      NaN           -2.431773                 NaN
# 1                -2.464557                 NaN                 NaN
# 136895           -1.955951           -1.782856           -1.819310
# 136896                 NaN           -2.593016           -2.656962
#
#         mln_mln_share_2010  mln_mln_share_2011  mln_mln_share_2012  \
# 0                      NaN                 NaN                 NaN
# 1                -2.644796                 NaN                 NaN
# 136895           -1.681701           -1.938294           -1.991810
# 136896                 NaN           -2.509978           -2.487586
#
#         mln_mln_share_2013  mln_mln_share_2014  mln_mln_share_2015  \
# 0                      NaN           -2.700872                 NaN
# 1                -2.637250                 NaN           -2.554711
# 136895           -2.022657           -1.857286           -1.906872
# 136896           -2.551439                 NaN           -2.554724
#
#         mln_mln_share_2016
# 0                      NaN
# 1                      NaN
# 136895           -1.988397
# 136896                 NaN
#
# [4 rows x 68 columns]

# %%
widedf.shape
# Out:
# (136897, 68)

# %%
(widedf.isnull().sum().sum(), widedf.isna().sum().sum())
# Out:
# (1769493, 1769493)

# %%
preds, _ = learn.get_preds(ds_type=DatasetType.Test)
preds
# Out:
# tensor([-10.2225,  -8.8558,  -8.8231,  ..., -12.0232, -10.4836, -10.2712])

# %%
test_df[prediction_col] = preds.numpy()

# %%
test_df.ends(5)
# Out:
#        location_code hs_product_code  pred_ln_share
# 0                AGO            0101     -10.222484
# 1                AGO            0102      -8.855832
# 2                AGO            0103      -8.823141
# 3                AGO            0104      -8.502187
# 4                AGO            0105      -8.543881
# 141631           ZWE            9702     -12.431525
# 141632           ZWE            9703     -10.583432
# 141633           ZWE            9704     -12.023237
# 141634           ZWE            9705     -10.483632
# 141635           ZWE            9706     -10.271186

# %% [markdown]
# ### Do differences in prediction vs training year predict changes?

# %%
final_df = test_df.merge(widedf, on=[user_col, item_col], how='left')
final_df[f'diff_{year_train}_pred'] = final_df[rating_col + f'_{year_train}'] - final_df[prediction_col]
final_df[f'diff_{year_train+5}_{year_train}'] = final_df[rating_col + f'_{year_train+5}'] - final_df[rating_col + f'_{year_train}']

final_df.ends(3)
# Out:
#        location_code hs_product_code  pred_ln_share  ln_Xcp_1995  ln_Xcp_1996  \
# 0                AGO            0101     -10.222484          NaN          NaN
# 1                AGO            0102      -8.855832          NaN          NaN
# 2                AGO            0103      -8.823141          NaN          NaN
# 141633           ZWE            9704     -12.023237     6.815640    10.083849
# 141634           ZWE            9705     -10.483632    14.622040    13.699506
# 141635           ZWE            9706     -10.271186     9.547098     9.203014
#
#         ln_Xcp_1997  ln_Xcp_1998  ln_Xcp_1999  ln_Xcp_2000  ln_Xcp_2001  ...  \
# 0          8.520189          NaN          NaN          NaN          NaN  ...
# 1          9.416460          NaN          NaN    12.485283    13.003638  ...
# 2               NaN          NaN          NaN     7.997663     8.274612  ...
# 141633     6.992096     8.730529          NaN    11.816424          NaN  ...
# 141634    13.448133    13.852829    13.956676    14.413279    13.648790  ...
# 141635    10.535185     7.512071          NaN     4.691348    12.712776  ...
#
#         mln_mln_share_2009  mln_mln_share_2010  mln_mln_share_2011  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN           -2.644796                 NaN
# 2                      NaN                 NaN                 NaN
# 141633           -2.431307           -2.671017                 NaN
# 141634           -1.819310           -1.681701           -1.938294
# 141635           -2.656962                 NaN           -2.509978
#
#         mln_mln_share_2012  mln_mln_share_2013  mln_mln_share_2014  \
# 0                      NaN                 NaN           -2.700872
# 1                      NaN           -2.637250                 NaN
# 2                      NaN                 NaN                 NaN
# 141633           -2.692322           -2.622044           -2.617213
# 141634           -1.991810           -2.022657           -1.857286
# 141635           -2.487586           -2.551439                 NaN
#
#         mln_mln_share_2015  mln_mln_share_2016  diff_1995_pred  diff_2000_1995
# 0                      NaN                 NaN             NaN             NaN
# 1                -2.554711                 NaN             NaN             NaN
# 2                      NaN                 NaN             NaN             NaN
# 141633           -2.599792           -2.629832       -2.510571        5.065960
# 141634           -1.906872           -1.988397        3.756225       -0.143585
# 141635           -2.554724                 NaN       -1.531164       -4.790574
#
# [6 rows x 71 columns]

# %%
fig = plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.scatter(final_df[rating_col+f'_{year_train+5}'].values, final_df[rating_col+f'_{year_train}'].values, alpha=0.2)
plt.plot([-20, 0], [-20, 0])
plt.xlabel("Real data in year previous/next to Training Year")
plt.ylabel("Real data in Training Year")

plt.subplot(1, 2, 2)
plt.scatter(final_df[prediction_col].values, final_df[rating_col+f'_{year_train}'].values, alpha=0.2)
plt.plot([-20, 0], [-20, 0])
plt.xlabel("Predicted from model")
plt.ylabel("Real data in Training Year")

plt.show()

# %%
('RMSE of next 5 with training gives RMSE = {:.3f}'.format(my_rmse(final_df[rating_col+f'_{year_train+5}'], 
                                                                final_df[rating_col+f'_{year_train}'])),
'RMSE of training with model gives RMSE = {:.3f}'.format(my_rmse(final_df[prediction_col], 
                                                                final_df[rating_col+f'_{year_train}'])))
# Out:
# ('RMSE of next 5 with training gives RMSE = 1.626',
#  'RMSE of training with model gives RMSE = 1.407')

# %% [markdown]
# We want to understand changes in the export baskets, from $r_{c,p}(t)$ to $r_{c,p}(t+\Delta t)$. Let us denote this change with the letter 'g', from 'growth':
#
# $$
# g_{c,p}(t) = r_{c,p}(t+\Delta t) - r_{c,p}(t).
# $$
#
# Let us compute the difference between the prediction from the model, and the real data:
#
# $$
# D_{c,p}(t) = r_{c,p}(t) - \widehat{r_{c,p}}(t).
# $$
#
# The question is whether the following regression specification is statistically predictive:
#
# $$
# g_{c,p}(t) = \beta_0 + \beta_1 r_{c,p}(t) + \beta_2 D_{c,p}(t) + \varepsilon_{c,p,t}.
# $$

# %% [markdown]
# This regression model states that the change from one period to the next is a linear function of
# - an intercept (i.e., perhaps there is an average tendency for change), which we expect to be positive,
# - the current level (i.e., perhaps there is some sort of reversion to the mean, whereby atypical high levels of $r_{c,p}(t)$ are followed by a subsequent decrease), with a coefficient we expect to be negative,
# - and the deviation between the current level and what our collaborative filtering model stated $r_{c,p}(t)$ _should_ have been (i.e., perhaps reality is always trying to revert back to some expected value), with a coefficient we also expect to be negative.

# %% [markdown]
# We note that the model could in principle be re-written as:
# $$
# r_{c,p}(t+\Delta t) - r_{c,p}(t) = \beta_0 + \beta_1 r_{c,p}(t) + \beta_2 (r_{c,p}(t) - \widehat{r_{c,p}}(t)) + \varepsilon_{c,p,t},
# $$
# which becomes
#
# $$
# r_{c,p}(t+\Delta t) = \beta_0 + (1 + \beta_1 + \beta_2) r_{c,p}(t) - \beta_2 \widehat{r_{c,p}}(t) + \varepsilon_{c,p,t},
# $$
#
# and modeled as
#
# $$
# r_{c,p}(t+\Delta t) = \alpha_0 + \alpha_1 r_{c,p}(t) + \alpha_2 \widehat{r_{c,p}}(t) + \varepsilon_{c,p,t},
# $$

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
results = smf.ols(f'diff_{year_train+5}_{year_train} ~ {rating_col}_{year_train} + diff_{year_train}_pred', 
                  data=final_df).fit()

# Inspect the results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         diff_2000_1995   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     8710.
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):               0.00
# Time:                        16:36:46   Log-Likelihood:            -1.7032e+05
# No. Observations:               93611   AIC:                         3.406e+05
# Df Residuals:                   93608   BIC:                         3.407e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -0.3096      0.025    -12.605      0.000      -0.358      -0.261
# ln_share_1995     -0.0312      0.002    -12.621      0.000      -0.036      -0.026
# diff_1995_pred    -0.4219      0.005    -90.991      0.000      -0.431      -0.413
# ==============================================================================
# Omnibus:                     8667.140   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32110.464
# Skew:                          -0.429   Prob(JB):                         0.00
# Kurtosis:                       5.738   Cond. No.                         51.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
results2 = smf.ols(f'{rating_col}_{year_train+5} ~ {rating_col}_{year_train} + {prediction_col}', 
                  data=final_df).fit()

# Inspect the results
print(results2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ln_share_2000   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                 1.005e+05
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):               0.00
# Time:                        16:36:46   Log-Likelihood:            -1.7032e+05
# No. Observations:               93611   AIC:                         3.406e+05
# Df Residuals:                   93608   BIC:                         3.407e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.3096      0.025    -12.605      0.000      -0.358      -0.261
# ln_share_1995     0.5468      0.004    154.133      0.000       0.540       0.554
# pred_ln_share     0.4219      0.005     90.991      0.000       0.413       0.431
# ==============================================================================
# Omnibus:                     8667.140   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32110.464
# Skew:                          -0.429   Prob(JB):                         0.00
# Kurtosis:                       5.738   Cond. No.                         71.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig = plt.figure(figsize=(12,10))
fig = sm.graphics.plot_partregress_grid(results, fig=fig)

# %%
# fix, ax = plt.subplots(figsize=(12,14))
# fig = sm.graphics.plot_partregress(f'diff_{year_train+5}_{year_train}', f'diff_{year_train}_pred', 
#                                    [f'{rating_col}_{year_train}'], 
#                                    data=final_df[~final_df[f'diff_{year_train+5}_{year_train}'].isnull()], 
#                                    ax=ax)

# %% [markdown]
# # Prediction at the extensive margin

# %% [markdown]
# All previous predictions were done at the intensive margin. That is, for a given country, we looked at the products that were exported in the training year and then were also exported in the next year, and looked whether a model could explain the change in that period of time.
#
# Here, we want to look at the country-product combinations that were missing in the current training year data, and see if we can predict/explain the time of appearance.

# %% [markdown]
# People typically do this by creating binary variables to model whether the product "appeared" or not in a fixed time window. That is, people typically define the following matrix:
# \begin{eqnarray}
#     A_{c,p}(t+\Delta t) =
#     \begin{cases}
#     1,\quad\text{if}~r_{c,p}(t)=0~\&~r_{c,p}(t+\Delta t)>0 \\
#     0,\quad\text{otherwise}
#     \end{cases}
# \end{eqnarray}
# or something like that (e.g., they might add some conditions that the production needs to be sustained for more than one period).

# %% [markdown]
# Here, however, I am going to take a different route. My hypothesis is that the larger $\widehat{r_{c,p}}(t)$, the more likely it is the product will appear soon, rather than later.

# %% [markdown]
# Thus, we create the following matrix:
#
# \begin{eqnarray}
#     T_{c,p}(t) = \text{min}\left\{\tau~:~r_{c,p}(t)=0~\&~r_{c,p}(t+\tau)>0\right\}.
# \end{eqnarray}
#
# That is, it is the matrix in which the element is the number of years until the product is exported, conditioned it is currently not being exported.
#
# Our dataset goes from 1995 until 2015, and 20 years is not a long time. Hence, a better exercise would be to use the SITC data which starts in 1962.

# %% [markdown]
# A simple regression model to test this hypothesis would be:
#
# \begin{eqnarray}
#     T_{c,p}(t) = \theta_0 + \theta_1 \widehat{r_{c,p}}(t) + \varepsilon_{c,p,t}
# \end{eqnarray}

# %% [markdown]
# ### Let's create the corresponding column of "time until appearance"

# %%
final_df.head(5)
# Out:
#   location_code hs_product_code  pred_ln_share  ln_Xcp_1995  ln_Xcp_1996  \
# 0           AGO            0101     -10.222484          NaN          NaN
# 1           AGO            0102      -8.855832          NaN          NaN
# 2           AGO            0103      -8.823141          NaN          NaN
# 3           AGO            0104      -8.502187          NaN          NaN
# 4           AGO            0105      -8.543881          NaN          NaN
#
#    ln_Xcp_1997  ln_Xcp_1998  ln_Xcp_1999  ln_Xcp_2000  ln_Xcp_2001  ...  \
# 0     8.520189          NaN          NaN          NaN          NaN  ...
# 1     9.416460          NaN          NaN    12.485283    13.003638  ...
# 2          NaN          NaN          NaN     7.997663     8.274612  ...
# 3          NaN          NaN          NaN    10.956649    10.965488  ...
# 4          NaN          NaN          NaN          NaN     6.259581  ...
#
#    mln_mln_share_2009  mln_mln_share_2010  mln_mln_share_2011  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN           -2.644796                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    mln_mln_share_2012  mln_mln_share_2013  mln_mln_share_2014  \
# 0                 NaN                 NaN           -2.700872
# 1                 NaN            -2.63725                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    mln_mln_share_2015  mln_mln_share_2016  diff_1995_pred  diff_2000_1995
# 0                 NaN                 NaN             NaN             NaN
# 1           -2.554711                 NaN             NaN             NaN
# 2                 NaN                 NaN             NaN             NaN
# 3                 NaN                 NaN             NaN             NaN
# 4                 NaN                 NaN             NaN             NaN
#
# [5 rows x 71 columns]

# %%
allyears = sorted(collab_df.year.unique())
print(allyears)

cols2look = [rating_col+f'_{tau}' for tau in allyears]
print(cols2look)
# Out:
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# ['ln_share_1995', 'ln_share_1996', 'ln_share_1997', 'ln_share_1998', 'ln_share_1999', 'ln_share_2000', 'ln_share_2001', 'ln_share_2002', 'ln_share_2003', 'ln_share_2004', 'ln_share_2005', 'ln_share_2006', 'ln_share_2007', 'ln_share_2008', 'ln_share_2009', 'ln_share_2010', 'ln_share_2011', 'ln_share_2012', 'ln_share_2013', 'ln_share_2014', 'ln_share_2015', 'ln_share_2016']

# %%
colnchar = len(rating_col)
sinit = colnchar + 1
sfinl = colnchar + 1 + 4
final_df['Tcp'] = 0.0
final_df['Tcp'] = final_df[cols2look].isnull().idxmin(axis=1).apply(lambda s: int(s[sinit:sfinl]) - year_train)
final_df.loc[final_df[cols2look].isnull().apply(all, axis=1), 'Tcp'] = np.nan

# %%
final_df.ends(3)
# Out:
#        location_code hs_product_code  pred_ln_share  ln_Xcp_1995  ln_Xcp_1996  \
# 0                AGO            0101     -10.222484          NaN          NaN
# 1                AGO            0102      -8.855832          NaN          NaN
# 2                AGO            0103      -8.823141          NaN          NaN
# 141633           ZWE            9704     -12.023237     6.815640    10.083849
# 141634           ZWE            9705     -10.483632    14.622040    13.699506
# 141635           ZWE            9706     -10.271186     9.547098     9.203014
#
#         ln_Xcp_1997  ln_Xcp_1998  ln_Xcp_1999  ln_Xcp_2000  ln_Xcp_2001  ...  \
# 0          8.520189          NaN          NaN          NaN          NaN  ...
# 1          9.416460          NaN          NaN    12.485283    13.003638  ...
# 2               NaN          NaN          NaN     7.997663     8.274612  ...
# 141633     6.992096     8.730529          NaN    11.816424          NaN  ...
# 141634    13.448133    13.852829    13.956676    14.413279    13.648790  ...
# 141635    10.535185     7.512071          NaN     4.691348    12.712776  ...
#
#         mln_mln_share_2010  mln_mln_share_2011  mln_mln_share_2012  \
# 0                      NaN                 NaN                 NaN
# 1                -2.644796                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 141633           -2.671017                 NaN           -2.692322
# 141634           -1.681701           -1.938294           -1.991810
# 141635                 NaN           -2.509978           -2.487586
#
#         mln_mln_share_2013  mln_mln_share_2014  mln_mln_share_2015  \
# 0                      NaN           -2.700872                 NaN
# 1                -2.637250                 NaN           -2.554711
# 2                      NaN                 NaN                 NaN
# 141633           -2.622044           -2.617213           -2.599792
# 141634           -2.022657           -1.857286           -1.906872
# 141635           -2.551439                 NaN           -2.554724
#
#         mln_mln_share_2016  diff_1995_pred  diff_2000_1995  Tcp
# 0                      NaN             NaN             NaN  2.0
# 1                      NaN             NaN             NaN  2.0
# 2                      NaN             NaN             NaN  5.0
# 141633           -2.629832       -2.510571        5.065960  0.0
# 141634           -1.988397        3.756225       -0.143585  0.0
# 141635                 NaN       -1.531164       -4.790574  0.0
#
# [6 rows x 72 columns]

# %%
final_df.loc[final_df['Tcp']>0, 'Tcp'].hist(bins=21)

# %%
final_df['Tcp'].describe()
# Out:
# count    136897.000000
# mean          1.388131
# std           3.361789
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max          21.000000
# Name: Tcp, dtype: float64

# %%
ax1 = final_df.plot.scatter(x=prediction_col,
                      y='Tcp',
                      c='DarkBlue')

# %% [markdown]
# ### Let's run the regression

# %%
extensive_ols = smf.ols(f'Tcp ~ {prediction_col}', 
                  data=final_df[final_df['Tcp']>0]).fit()

# Inspect the results
print(extensive_ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Tcp   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5094
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):              0.475
# Time:                        17:03:09   Log-Likelihood:            -1.1096e+05
# No. Observations:               37263   AIC:                         2.219e+05
# Df Residuals:                   37261   BIC:                         2.219e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         5.2232      0.175     29.884      0.000       4.881       5.566
# pred_ln_share     0.0113      0.016      0.714      0.475      -0.020       0.042
# ==============================================================================
# Omnibus:                     7727.819   Durbin-Watson:                   1.552
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13633.001
# Skew:                           1.363   Prob(JB):                         0.00
# Kurtosis:                       4.160   Cond. No.                         79.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig = plt.figure(figsize=(6,10))
fig = sm.graphics.plot_partregress_grid(extensive_ols, fig=fig)

# %%
aggregations = {f'{prediction_col}': {
    'mean_Tcp': 'mean',
    'std_Tcp': 'std'
}
               }

# %%
final_df['Tcp']
# Out:
# 3.361788718839251

# %% [markdown]
# # Check on a new data set

# %%
def score_direct(learner, test_df, user_col, item_col, prediction_col, top_k=0):
    """score all users+movies provided and reduce to top_k items per user if top_k>0"""
    # replace values not known to the model with #na#
    total_users, total_items = learner.data.classes.values()
    test_df.loc[~test_df[user_col].isin(total_users),user_col] = total_users[0]
    test_df.loc[~test_df[item_col].isin(total_items),item_col] = total_items[0]
   
    # map ids to embedding ids 
    u = learner.get_idx(test_df[user_col], is_item=False)
    m = learner.get_idx(test_df[item_col], is_item=True)
    
    # score the pytorch model
    pred = learner.model.forward(u, m)
    scores = pd.DataFrame({user_col: test_df[user_col], item_col:test_df[item_col], prediction_col:pred})
    scores =  scores.sort_values([user_col,prediction_col],ascending=[True,False])
    if top_k > 0:
        top_scores = scores.groupby(user_col).head(top_k).reset_index(drop=True)
    else:
        top_scores = scores
    return(top_scores)

# %%
score_direct(learn, collab_df[collab_df['year']==year_train], 
             user_col='location_code',
             item_col='hs_product_code',
             prediction_col='pred',
             top_k=10)

# %%
# alldata = (CollabList.from_df(collab_df, path=PATH)
#         .no_split()
#         .label_from_folder()
#         .transform(tfms)
#         .databunch()
#         .normalize()
#        ) 
# alldata = CollabDataBunch.from_df(collab_df, 
#                           user_name = 'location_code',
#                           item_name = 'hs_product_code',
#                           rating_name = 'y',
#                            seed = 42,
#                           test = collab_df[collab_df['year']==2015],
#                           path = PATH)

# %%
# data = (TabularList.from_df(df, path=adult, cat_names=cat_names, cont_names=cont_names, procs=procs)
#                            .split_by_idx(valid_idx=range(800,1000))
#                            .label_from_df(cols=dep_var)
#                            .databunch())

# %%
# from fastai.tabular import *

# %%
# dep_var = 'salary'
# cat_names = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
# cont_names = ['education-num', 'hours-per-week', 'age', 'capital-loss', 'fnlwgt', 'capital-gain']
# procs = [FillMissing, Categorify, Normalize]
